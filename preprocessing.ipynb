# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
whole_df = pd.read_csv('data/transfer_data.csv')

# %%
whole_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4700 entries, 0 to 4699
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          4700 non-null   object
#  1   Position      4700 non-null   object
#  2   Age           4700 non-null   int64
#  3   Team_from     4700 non-null   object
#  4   League_from   4700 non-null   object
#  5   Team_to       4700 non-null   object
#  6   League_to     4700 non-null   object
#  7   Season        4700 non-null   object
#  8   Market_value  3440 non-null   float64
#  9   Transfer_fee  4700 non-null   int64
# dtypes: float64(1), int64(2), object(7)
# memory usage: 367.3+ KB

# %%
whole_df.columns
# Out:
# Index(['Name', 'Position', 'Age', 'Team_from', 'League_from', 'Team_to',
#        'League_to', 'Season', 'Market_value', 'Transfer_fee'],
#       dtype='object')

# %%
whole_df['Market_value']
# Out:
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#           ...
# 4695    5000000.0
# 4696    3000000.0
# 4697    8500000.0
# 4698    4500000.0
# 4699    3500000.0
# Name: Market_value, Length: 4700, dtype: float64

# %%
whole_df['Market_value'].isnull().sum().sum()
# Out:
# 1260

# %%
whole_df.hist(['Transfer_fee'])
# Out:
# array([[<AxesSubplot:title={'center':'Transfer_fee'}>]], dtype=object)

# %%
whole_df["Name"]
# Out:
# 0               Luís Figo
# 1           Hernán Crespo
# 2           Marc Overmars
# 3       Gabriel Batistuta
# 4          Nicolas Anelka
#               ...
# 4695        Jasmin Kurtic
# 4696            Tchê Tchê
# 4697        Silvan Widmer
# 4698           Yuya Osako
# 4699         Kyle Bartley
# Name: Name, Length: 4700, dtype: object

# %%
whole_df["Transfer_fee"]
# Out:
# 0       60000000
# 1       56810000
# 2       40000000
# 3       36150000
# 4       34500000
#           ...
# 4695     4800000
# 4696     4800000
# 4697     4500000
# 4698     4500000
# 4699     4500000
# Name: Transfer_fee, Length: 4700, dtype: int64

# %%
whole_df["Transfer_fee"].isnull().sum()
# Out:
# 0

# %% [markdown]
# whole_df["Transfer_fee].info

# %%
fig, ax = plt.subplots()
ax.plot(whole_df[whole_df["Season"] == '2003-2004']['Transfer_fee'])
ax.ticklabel_format(useOffset=False)
plt.show()
#plt.plot(whole_df[whole_df["Season"] == '2002-2003']['Transfer_fee'])

# %%
plt.plot(whole_df['Transfer_fee'])

# %%
plt.plot(whole_df["Age"])

# %%
len(whole_df[whole_df["Age"]> 22])
# Out:
# 3284

# %%
whole_df["Age"].unique()
# Out:
# array([27, 25, 31, 21, 22, 26, 28, 23, 19, 24, 30, 20, 29, 35, 18, 32,  0,
#        33, 34, 17, 16, 15])

# %%
whole_df[whole_df["Age"] == 0]
# Out:
#                   Name        Position  Age Team_from    League_from  Team_to  \
# 236  Marzouq Al-Otaibi  Centre-Forward    0    Shabab   Saudi Arabia  Ittihad
#
#          League_to     Season  Market_value  Transfer_fee
# 236   Saudi Arabia  2000-2001           NaN       2000000

# %%
import requests
 
# get URL
page = requests.get("https://en.wikipedia.org/wiki/Ricardo_Goulart")
 
# display status code
print(page.status_code)
 
# display scrapped data
#print(page.content
# Out:
# 200

# %%
# !pip install bs4
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached beautifulsoup4-4.10.0-py3-none-any.whl (97 kB)
# ...
#   Using cached soupsieve-2.3.1-py3-none-any.whl (37 kB)
# ...
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1271 sha256=3a3ac435f1daa9529c11620304a1cd8b370a378dc2cd6638a1c1cef4b4203499
#   Stored in directory: /Users/parthvyas/Library/Caches/pip/wheels/73/2b/cb/099980278a0c9a3e57ff1a89875ec07bfa0b6fcbebb9a8cad3
# Successfully built bs4
# ...

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(page.content, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Ricardo Goulart - Wikipedia
#   </title>
#   <script>
# ...

# %%
#object = soup.find_all(id ="tr")
details = soup("table", {"class": "infobox-label"})
#items = object.find_all(class_="mp-h2")
print(details)
for item in details:
    h = item.find_all("th")
    print(h)
# Out:
# []

# %%
#get the text for soup.find_all("tr")

# %%
for i in soup.find_all("table", {"class": "infobox vcard"}):
    for j in i.find_all("td", {"class": "infobox-data birthplace"}):
        print(j.text)
# Out:
# São José dos Campos, Brazil

# %%
for i in soup.find_all("table"):
    for row in i.find_all("tr"):
        for cell in row.find_all("td"):
            print(cell.text)
# Out:
# Ricardo Goulart Pereira
#
#  (1991-06-05) 5 June 1991 (age 30)
#
# São José dos Campos, Brazil
#
# 1.80 m (5 ft 11 in)
#
# Attacking midfielder
#
# Santos
#
# 10
#
# Moreira's Sport
#
# Santo André
#
# Team
#
# Apps
#
# (Gls)
#
# Santo André
#
# 34
#
# (6)
#
# → Internacional (loan)
#
# 17
#
# (5)
#
# Goiás
#
# 55
#
# (21)
#
# Cruzeiro
#
# 79
#
# (29)
#
# Guangzhou
#
# 117
#
# (78)
#
# → Palmeiras (loan)
#
# 9
#
# (3)
#
# → Hebei China Fortune (loan)
#
# 18
#
# (4)
#
# Santos
#
# 9
#
# (3)
#
# Brazil
#
# 1
#
# (0)
#
# * Senior club appearances and goals counted for the domestic league only and correct as of 19:22, 23 March 2022 (UTC)‡ National team caps and goals correct as of 9 September 2014
# Santo André
#
# 2009
#
# Série A
#
# 14
# 1
# 12[a]
# 4
# —
# —
# —
# 26
# 5
#
# 2010
#
# Série A
#
# 0
# 0
# 8[a]
# 1
# —
# —
# —
# 8
# 1
#
# Internacional (loan)
#
# 2010
#
# Série A
#
# 0
# 0
# —
# —
# —
# 13[b]
# 6
# 13
# 6
#
# 2011
#
# Série A
#
# 10
# 1
# 7[c]
# 4
# —
# 1[d]
# 0
# —
# ...

# %%
def get_(search_string):
    final_string = ""
    for i in search_string.split():
        final_string = final_string + i + '_'
    return final_string[:-1]



def get_table_data(search_query):
    url = "https://en.wikipedia.org/wiki/" + search_query
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')
    table = soup.find_all("table")
    nation = ""
    for i in soup.find_all("table", {"class": "infobox vcard"}):
        for j in i.find_all("td", {"class": "infobox-data birthplace"}):
            if i is not None and j is not None:
                nation = j.text.split(", ")[-1]

    return nation

# %%
get_("Jimmy Floyd Hasselbaink")
# Out:
# 'Jimmy_Floyd_Hasselbaink'

# %%
get_table_data('Jimmy_Floyd_Hasselbaink')
# Out:
# 'Suriname'

# %%
url = "https://en.wikipedia.org/wiki/" + "Jimmy_Floyd_Hasselbaink"
page = requests.get(url)
soup = BeautifulSoup(page.content, 'html.parser')
table = soup.find_all("table")
for i in soup.find_all("table", {"class": "infobox vcard"}):
    print(i)
# Out:
# <table class="infobox vcard" style="line-height: 1.2em;"><caption class="infobox-title fn" style="font-size: 125%; text-align: center; line-height: 1.2em;">Jimmy Floyd Hasselbaink</caption><tbody><tr><td class="infobox-image" colspan="4">
# ...

# %%
url = "https://en.wikipedia.org/wiki/" + "Jimmy_Floyd_Hasselbaink"
page = requests.get(url)
soup = BeautifulSoup(page.content, 'html.parser')
table = soup.find_all("table")
for i in soup.find_all("table", {"class": "infobox vcard"}):
    for j in i.find_all("td", {"class": "infobox-data infobox-data-a"}):
        print(j.text)
# Out:
# Team
#
# Telstar
#
# AZ Alkmaar
#
# Neerlandia
#
# Campomaiorense
#
# Boavista
#
# Leeds United
#
# Atlético Madrid
#
# Chelsea
#
# Middlesbrough
#
# Charlton Athletic
#
# Cardiff City
#
#
#
# Netherlands

# %%
url = "https://en.wikipedia.org/wiki/" + "Jimmy_Floyd_Hasselbaink"
page = requests.get(url)
soup = BeautifulSoup(page.content, 'html.parser')

# %%
b = "São José dos Campos, Brazil"
b.split(", ")[-1]
# Out:
# 'Brazil'
